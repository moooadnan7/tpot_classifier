# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import train_test_split
data= pd.read_csv('/content/fetal_health classification project.csv')
x_train,x_test,y_train,y_test=train_test_split(data.drop('fetal_health',axis=1),data['fetal_health'],test_size=0.2,random_state=42)

# %%
# !pip install tpot
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.4/87.4 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 5.4 MB/s eta 0:00:00
# ...
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11939 sha256=7aaac28c971934f02e0e8738c39cefed8f7d0c5fe159c057384d3233b98bf660
#   Stored in directory: /root/.cache/pip/wheels/af/f9/87/bf5b3d565c2a007b4dae9d8142dccc85a9f164e517062dd519
# Successfully built stopit
# ...

# %%
from tpot import TPOTClassifier
tpot=TPOTClassifier(generations=3,population_size=50,verbosity=2,random_state=42,scoring='accuracy')
tpot.fit(x_train,y_train)
# Out:
# Optimization Progress:   0%|          | 0/200 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: 0.9464705882352942
#
# Generation 2 - Current best internal CV score: 0.9482352941176471
#
# Generation 3 - Current best internal CV score: 0.951764705882353
#
# Best pipeline: GradientBoostingClassifier(ZeroCount(input_matrix), learning_rate=0.1, max_depth=6, max_features=0.15000000000000002, min_samples_leaf=17, min_samples_split=18, n_estimators=100, subsample=0.9500000000000001)
# TPOTClassifier(generations=3, population_size=50, random_state=42,
#                scoring='accuracy', verbosity=2)

# %%
tpot.score(x_test,y_test)
# Out:
# 0.9530516431924883
